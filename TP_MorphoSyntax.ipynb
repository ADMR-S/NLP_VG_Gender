# %% [markdown]
# **Morpho-syntactic analysis with NLTK (https://www.nltk.org/)**
# Goal of this tutorial is to understand and then test several NLTK and SpaCy functions for pre-processing and text vectorization. I'll give you an example for each feature, so take the time to test with other sentences and understand how to manipulate this type of text data.
#
# **Tokenisation and POS tagging** avec NLTK:

# %%
# %pip install nltk
# Out:
# Collecting nltkNote: you may need to restart the kernel to use updated packages.
#
#   Using cached nltk-3.9.1-py3-none-any.whl (1.5 MB)
# Collecting click
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting regex>=2021.8.3
#   Downloading regex-2024.11.6-cp38-cp38-win_amd64.whl (274 kB)
# Collecting tqdm
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting joblib
#   Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\adam\appdata\roaming\python\python38\site-packages (from click->nltk) (0.4.6)
# Installing collected packages: click, regex, tqdm, joblib, nltk
# Successfully installed click-8.1.8 joblib-1.4.2 nltk-3.9.1 regex-2024.11.6 tqdm-4.67.1
#   WARNING: The script tqdm.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script nltk.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 20.2.1; however, version 25.0.1 is available.
# You should consider upgrading via the 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\python.exe -m pip install --upgrade pip' command.

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
text = nltk.word_tokenize("Today is raining!")
nltk.pos_tag(text)
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\Adam\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Adam\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# [('Today', 'NN'), ('is', 'VBZ'), ('raining', 'VBG'), ('!', '.')]

# %% [markdown]
# Découvrons quelles sont les étiquettes les plus courantes dans la catégorie NEWS du corpus Brown:

# %%
from nltk.corpus import brown
nltk.download('brown')
nltk.download('universal_tagset')
brown_news_tagged = brown.tagged_words(categories='news',tagset='universal')
tag_fd = nltk.FreqDist(tag for (word, tag) in brown_news_tagged)
tag_fd.most_common()
# Out:
# [nltk_data] Downloading package brown to
# [nltk_data]     C:\Users\Adam\AppData\Roaming\nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     C:\Users\Adam\AppData\Roaming\nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# [('NOUN', 30654),
#  ('VERB', 14399),
#  ('ADP', 12355),
#  ('.', 11928),
#  ('DET', 11389),
#  ('ADJ', 6706),
#  ('ADV', 3349),
#  ('CONJ', 2717),
#  ('PRON', 2535),
#  ('PRT', 2264),
#  ('NUM', 2166),
#  ('X', 92)]

# %% [markdown]
# **Stemming** with NLTK.

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()

for word in ['walking', 'walks', 'walked']:
    print(porter.stem(word))
# Out:
# walk
# walk
# walk

# %% [markdown]
# **Distribution des mots dans le texte**
#
# La méthode text.similar() prend un mot w, recherche tous les contextes w1 w w2, puis tous les mots w’ qui apparaissent dans le même contexte, c.-à-d. w1 w’ w2

# %%
text = nltk.Text(word.lower() for word in nltk.corpus.brown.words())
#text.similar('woman')
#Testez les mots suivants et d'autres mots:
text.similar('bought')
#text.similar('the')
# Out:
# made said done put had seen found given left heard was been brought
# set got that took in told felt

# %% [markdown]
# **Commment créer une CFG?**
#
# Définissons une grammaire et voyons comment analyser une phrase simple admise par la grammaire.
#
# Quelles phrases peut reconnaître cette grammaire?

# %%
from nltk.corpus import treebank
grammar1 = nltk.CFG.fromstring("""
S -> NP VP
VP -> V NP | V NP PP
PP -> P NP
V -> 'saw' | 'ate' | 'walked' | 'chase'
NP -> 'John' | 'Mary' | 'Bob' | Det N | Det N PP | N
Det -> 'a' | 'an' | 'the' | 'my'
N -> 'man' | 'dog' | 'cat' | 'telescope' | 'park'| 'dogs' | 'cats'
P -> 'in' | 'on' | 'by' | 'with'
""")
#sent = "Mary saw Bob".split()
sent = "dogs chase cats".split()
rd_parser = nltk.RecursiveDescentParser(grammar1)
for tree in rd_parser.parse(sent):
  print(tree)
# Out:
# (S (NP (N dogs)) (VP (V chase) (NP (N cats))))

# %% [markdown]
# Modifiez la grammaire pour que elle puisse reconnaitre la phrase: "dogs chase cats". Testez avec NLTK!!

# %%
#Testez ici!!

# %% [markdown]
# **Une CFG pour le Français.** Quelles phrases peut reconnaître cette grammaire?
#
# Modifiez la grammaire pour que elle puisse reconnaitre des autres phrases!

# %%
grammaire = nltk.CFG.fromstring("""
S -> SN SV
SN -> Art Nom
SV -> V SN | V
Nom -> 'chien' | 'chat'
Art -> 'le'
V -> 'mange'
V -> 'dort'
""")
sent = "le chien dort".split()
rd_parser = nltk.RecursiveDescentParser(grammaire)
for tree in rd_parser.parse(sent):
  print(tree)
# Out:
# (S (SN (Art le) (Nom chien)) (SV (V dort)))

# %% [markdown]
# Testons maintenant l'outil SpaCy, une autre bibliothèque open-source pour le traitement avancé du langage naturel en Python.

# %%
# %pip install -U pip setuptools wheel
# %pip install -U spacy==3.5.0
# Out:
# Collecting pipNote: you may need to restart the kernel to use updated packages.
#
#   Using cached pip-25.0.1-py3-none-any.whl (1.8 MB)
# Collecting setuptools
#   Using cached setuptools-75.3.2-py3-none-any.whl (1.3 MB)
# Collecting wheel
#   Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Installing collected packages: pip, setuptools, wheel
#   Attempting uninstall: pip
#     Found existing installation: pip 20.2.1
#     Uninstalling pip-20.2.1:
#       Successfully uninstalled pip-20.2.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 49.2.1
#     Uninstalling setuptools-49.2.1:
#       Successfully uninstalled setuptools-49.2.1
# Successfully installed pip-25.0.1 setuptools-75.3.2 wheel-0.45.1
#   WARNING: The scripts pip.exe, pip3.8.exe and pip3.exe are installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script wheel.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Collecting spacy==3.5.0
#   Downloading spacy-3.5.0-cp38-cp38-win_amd64.whl.metadata (25 kB)
# Collecting spacy-legacy<3.1.0,>=3.0.11 (from spacy==3.5.0)
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting spacy-loggers<2.0.0,>=1.0.0 (from spacy==3.5.0)
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# Collecting murmurhash<1.1.0,>=0.28.0 (from spacy==3.5.0)
#   Using cached murmurhash-1.0.12.tar.gz (13 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting cymem<2.1.0,>=2.0.2 (from spacy==3.5.0)
#   Using cached cymem-2.0.11.tar.gz (10 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting preshed<3.1.0,>=3.0.2 (from spacy==3.5.0)
#   Downloading preshed-3.0.9-cp38-cp38-win_amd64.whl.metadata (2.2 kB)
# Collecting thinc<8.2.0,>=8.1.0 (from spacy==3.5.0)
#   Downloading thinc-8.1.12-cp38-cp38-win_amd64.whl.metadata (15 kB)
# Collecting wasabi<1.2.0,>=0.9.1 (from spacy==3.5.0)
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# Collecting srsly<3.0.0,>=2.4.3 (from spacy==3.5.0)
#   Downloading srsly-2.4.8-cp38-cp38-win_amd64.whl.metadata (20 kB)
# Collecting catalogue<2.1.0,>=2.0.6 (from spacy==3.5.0)
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# Collecting typer<0.8.0,>=0.3.0 (from spacy==3.5.0)
#   Downloading typer-0.7.0-py3-none-any.whl.metadata (17 kB)
# Collecting pathy>=0.10.0 (from spacy==3.5.0)
#   Downloading pathy-0.11.0-py3-none-any.whl.metadata (16 kB)
# Collecting smart-open<7.0.0,>=5.2.1 (from spacy==3.5.0)
#   Downloading smart_open-6.4.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy==3.5.0) (4.67.1)
# Collecting numpy>=1.15.0 (from spacy==3.5.0)
#   Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl.metadata (5.6 kB)
# Collecting requests<3.0.0,>=2.13.0 (from spacy==3.5.0)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 (from spacy==3.5.0)
#   Downloading pydantic-1.10.21-cp38-cp38-win_amd64.whl.metadata (155 kB)
# Collecting jinja2 (from spacy==3.5.0)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: setuptools in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy==3.5.0) (75.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\appdata\roaming\python\python38\site-packages (from spacy==3.5.0) (24.2)
# Collecting langcodes<4.0.0,>=3.2.0 (from spacy==3.5.0)
#   Downloading langcodes-3.4.1-py3-none-any.whl.metadata (29 kB)
# Collecting language-data>=1.2 (from langcodes<4.0.0,>=3.2.0->spacy==3.5.0)
#   Using cached language_data-1.3.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pathlib-abc==0.1.1 (from pathy>=0.10.0->spacy==3.5.0)
#   Downloading pathlib_abc-0.1.1-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\adam\appdata\roaming\python\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy==3.5.0) (4.13.2)
# Collecting charset-normalizer<4,>=2 (from requests<3.0.0,>=2.13.0->spacy==3.5.0)
#   Downloading charset_normalizer-3.4.1-cp38-cp38-win_amd64.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3.0.0,>=2.13.0->spacy==3.5.0)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3.0.0,>=2.13.0->spacy==3.5.0)
#   Downloading urllib3-2.2.3-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests<3.0.0,>=2.13.0->spacy==3.5.0)
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# Collecting blis<0.8.0,>=0.7.8 (from thinc<8.2.0,>=8.1.0->spacy==3.5.0)
#   Downloading blis-0.7.11-cp38-cp38-win_amd64.whl.metadata (7.6 kB)
# Collecting confection<1.0.0,>=0.0.1 (from thinc<8.2.0,>=8.1.0->spacy==3.5.0)
#   Using cached confection-0.1.5-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: colorama in c:\users\adam\appdata\roaming\python\python38\site-packages (from tqdm<5.0.0,>=4.38.0->spacy==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy==3.5.0) (8.1.8)
# Collecting MarkupSafe>=2.0 (from jinja2->spacy==3.5.0)
#   Downloading MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl.metadata (3.1 kB)
# Collecting marisa-trie>=1.1.0 (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.5.0)
#   Downloading marisa_trie-1.2.1-cp38-cp38-win_amd64.whl.metadata (9.3 kB)
# Downloading spacy-3.5.0-cp38-cp38-win_amd64.whl (12.6 MB)
#    ---------------------------------------- 0.0/12.6 MB ? eta -:--:--
#    --------------------- ------------------ 6.8/12.6 MB 34.9 MB/s eta 0:00:01
#    ------------------------------- -------- 10.0/12.6 MB 24.8 MB/s eta 0:00:01
#    ---------------------------------------- 12.6/12.6 MB 23.9 MB/s eta 0:00:00
# Using cached catalogue-2.0.10-py3-none-any.whl (17 kB)
# Downloading langcodes-3.4.1-py3-none-any.whl (182 kB)
# Downloading numpy-1.24.4-cp38-cp38-win_amd64.whl (14.9 MB)
#    ---------------------------------------- 0.0/14.9 MB ? eta -:--:--
#    --------------------------- ------------ 10.2/14.9 MB 49.1 MB/s eta 0:00:01
#    ---------------------------------------  14.7/14.9 MB 48.5 MB/s eta 0:00:01
#    ---------------------------------------- 14.9/14.9 MB 30.2 MB/s eta 0:00:00
# Downloading pathy-0.11.0-py3-none-any.whl (47 kB)
# Downloading pathlib_abc-0.1.1-py3-none-any.whl (23 kB)
# Downloading preshed-3.0.9-cp38-cp38-win_amd64.whl (122 kB)
# Downloading pydantic-1.10.21-cp38-cp38-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 44.0 MB/s eta 0:00:00
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
# Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl (29 kB)
# Using cached spacy_loggers-1.0.5-py3-none-any.whl (22 kB)
# Downloading srsly-2.4.8-cp38-cp38-win_amd64.whl (483 kB)
# Downloading thinc-8.1.12-cp38-cp38-win_amd64.whl (1.5 MB)
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 1.5/1.5 MB 26.4 MB/s eta 0:00:00
# Downloading typer-0.7.0-py3-none-any.whl (38 kB)
# Using cached wasabi-1.1.3-py3-none-any.whl (27 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading blis-0.7.11-cp38-cp38-win_amd64.whl (6.6 MB)
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    ---------------------------------------- 6.6/6.6 MB 45.5 MB/s eta 0:00:00
# Using cached certifi-2025.1.31-py3-none-any.whl (166 kB)
# Downloading charset_normalizer-3.4.1-cp38-cp38-win_amd64.whl (102 kB)
# Using cached confection-0.1.5-py3-none-any.whl (35 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached language_data-1.3.0-py3-none-any.whl (5.4 MB)
# Downloading MarkupSafe-2.1.5-cp38-cp38-win_amd64.whl (17 kB)
# Downloading urllib3-2.2.3-py3-none-any.whl (126 kB)
# Downloading marisa_trie-1.2.1-cp38-cp38-win_amd64.whl (152 kB)
# Building wheels for collected packages: cymem, murmurhash
#   Building wheel for cymem (pyproject.toml): started
#   Building wheel for cymem (pyproject.toml): finished with status 'done'
#   Created wheel for cymem: filename=cymem-2.0.11-cp38-cp38-win_amd64.whl size=39463 sha256=9469f7846ffd500d34f9a60cd26980a08f63f31179beb2a2b8907ceb7986c061
#   Stored in directory: c:\users\adam\appdata\local\pip\cache\wheels\a9\45\9e\e01643f1bcc044859f97c48abbf20eeb61d96199e30d2bd919
#   Building wheel for murmurhash (pyproject.toml): started
#   Building wheel for murmurhash (pyproject.toml): finished with status 'done'
#   Created wheel for murmurhash: filename=murmurhash-1.0.12-cp38-cp38-win_amd64.whl size=25092 sha256=74e007d4ebe8cfe1c6066514a87a7c9fd89a47c7dd2f1672ad4802613667be88
#   Stored in directory: c:\users\adam\appdata\local\pip\cache\wheels\e9\11\9a\cf7bd1a6798e6a8f077cdc112205d2aa0eb43af139b86dc8af
# Successfully built cymem murmurhash
# Installing collected packages: cymem, wasabi, urllib3, spacy-loggers, spacy-legacy, smart-open, pydantic, pathlib-abc, numpy, murmurhash, MarkupSafe, marisa-trie, idna, charset-normalizer, certifi, catalogue, typer, srsly, requests, preshed, language-data, jinja2, blis, pathy, langcodes, confection, thinc, spacy
# Successfully installed MarkupSafe-2.1.5 blis-0.7.11 catalogue-2.0.10 certifi-2025.1.31 charset-normalizer-3.4.1 confection-0.1.5 cymem-2.0.11 idna-3.10 jinja2-3.1.6 langcodes-3.4.1 language-data-1.3.0 marisa-trie-1.2.1 murmurhash-1.0.12 numpy-1.24.4 pathlib-abc-0.1.1 pathy-0.11.0 preshed-3.0.9 pydantic-1.10.21 requests-2.32.3 smart-open-6.4.0 spacy-3.5.0 spacy-legacy-3.0.12 spacy-loggers-1.0.5 srsly-2.4.8 thinc-8.1.12 typer-0.7.0 urllib3-2.2.3 wasabi-1.1.3
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The script f2py.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script normalizer.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script pathy.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script spacy.exe is installed in 'c:\Users\Adam\AppData\Local\Programs\Python\Python38\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
# !python -m spacy download en_core_web_sm
# Out:
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ------------- -------------------------- 4.5/12.8 MB 26.9 MB/s eta 0:00:01
#      ---------------------------------- ---- 11.3/12.8 MB 29.4 MB/s eta 0:00:01
#      --------------------------------------  12.6/12.8 MB 29.3 MB/s eta 0:00:01
#      --------------------------------------- 12.8/12.8 MB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from en-core-web-sm==3.5.0) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.21)
# Requirement already satisfied: jinja2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (75.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\appdata\roaming\python\python38\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\adam\appdata\roaming\python\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.1.5)
# Requirement already satisfied: colorama in c:\users\adam\appdata\roaming\python\python38\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.2.1)
# Installing collected packages: en-core-web-sm
# Successfully installed en-core-web-sm-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
doc = nlp('Hello     World!')
for token in doc:
    print('"' + token.text + '"')
# Out:
# "Hello"
# "    "
# "World"
# "!"

# %%
# détection de phrases

doc = nlp("These are apples. These are oranges.")

for sent in doc.sents:
    print(sent)
# Out:
# These are apples.
# These are oranges.

# %%
# POS Tagging

doc = nlp("Next week I'll be in Madrid.")
print([(token.text, token.tag_) for token in doc])
# Out:
# [('Next', 'JJ'), ('week', 'NN'), ('I', 'PRP'), ("'ll", 'MD'), ('be', 'VB'), ('in', 'IN'), ('Madrid', 'NNP'), ('.', '.')]

# %%
# NER Named Entity Recognition

doc = nlp(u"Next week I'll be in Madrid.")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# Next week DATE
# Madrid GPE

# %%
# Spacy Entity Types

doc = nlp(u"I just bought 2 shares at 9 a.m. because the stock went up 30% in just 2 days according to the WSJ")
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# 2 CARDINAL
# 9 a.m. TIME
# 30% PERCENT
# just 2 days DATE
# WSJ ORG

# %%
# displaCy

from spacy import displacy

doc = nlp(u'I just bought 2 shares at 9 a.m. because the stock went up 30% in just 2 days according to the WSJ')
displacy.render(doc, style='ent', jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">I just bought
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  shares at
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     9 a.m.
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">TIME</span>
# </mark>
#  because the stock went up
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     30%
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERCENT</span>
# </mark>
#  in
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     just 2 days
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  according to the
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     WSJ
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </div></span>

# %%
# Chunking

doc = nlp("Wall Street Journal just published an interesting piece on crypto currencies")
for chunk in doc.noun_chunks:
    print(chunk.text, chunk.label_, chunk.root.text)
# Out:
# Wall Street Journal NP Journal
# an interesting piece NP piece
# crypto currencies NP currencies

# %%
# Dependency Parsing

doc = nlp('Wall Street Journal just published an interesting piece on crypto currencies')

for token in doc:
    print("{0}/{1} <--{2}-- {3}/{4}".format(
        token.text, token.tag_, token.dep_, token.head.text, token.head.tag_))
# Out:
# Wall/NNP <--compound-- Street/NNP
# Street/NNP <--compound-- Journal/NNP
# Journal/NNP <--nsubj-- published/VBD
# just/RB <--advmod-- published/VBD
# published/VBD <--ROOT-- published/VBD
# an/DT <--det-- piece/NN
# interesting/JJ <--amod-- piece/NN
# piece/NN <--dobj-- published/VBD
# on/IN <--prep-- piece/NN
# crypto/JJ <--amod-- currencies/NNS
# currencies/NNS <--pobj-- on/IN

# %%
# Visualisation des Dependency Parsing

from spacy import displacy

doc = nlp(u'Wall Street Journal just published an interesting piece on crypto currencies')
displacy.render(doc, style='dep', jupyter=True, options={'distance': 90})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="f0b2ede0638c4f54a8c00c45f1fdfb53-0" class="displacy" width="1040" height="272.0" direction="ltr" style="max-width: none; height: 272.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Wall</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">Street</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">Journal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">just</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">published</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">an</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">interesting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">piece</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">on</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">crypto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="182.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">currencies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-0" stroke-width="2px" d="M70,137.0 C70,92.0 130.0,92.0 130.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,139.0 L62,127.0 78,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-1" stroke-width="2px" d="M160,137.0 C160,92.0 220.0,92.0 220.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M160,139.0 L152,127.0 168,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-2" stroke-width="2px" d="M250,137.0 C250,47.0 405.0,47.0 405.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M250,139.0 L242,127.0 258,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-3" stroke-width="2px" d="M340,137.0 C340,92.0 400.0,92.0 400.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340,139.0 L332,127.0 348,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-4" stroke-width="2px" d="M520,137.0 C520,47.0 675.0,47.0 675.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M520,139.0 L512,127.0 528,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-5" stroke-width="2px" d="M610,137.0 C610,92.0 670.0,92.0 670.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M610,139.0 L602,127.0 618,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-6" stroke-width="2px" d="M430,137.0 C430,2.0 680.0,2.0 680.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">dobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M680.0,139.0 L688.0,127.0 672.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-7" stroke-width="2px" d="M700,137.0 C700,92.0 760.0,92.0 760.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M760.0,139.0 L768.0,127.0 752.0,127.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-f0b2ede0638c4f54a8c00c45f1fdfb53-0-8" stroke-width="2px" d="M880,137.0 C880,92.0 940.0,92.0 940.0,137.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#ar

# %%
# !python -m spacy download en_core_web_lg
# Out:
# Collecting en-core-web-lg==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.5.0/en_core_web_lg-3.5.0-py3-none-any.whl (587.7 MB)
#      ---------------------------------------- 0.0/587.7 MB ? eta -:--:--
#      --------------------------------------- 3.4/587.7 MB 20.2 MB/s eta 0:00:29
#       -------------------------------------- 9.2/587.7 MB 23.8 MB/s eta 0:00:25
#       ------------------------------------- 14.9/587.7 MB 24.7 MB/s eta 0:00:24
#      - ------------------------------------ 21.0/587.7 MB 26.0 MB/s eta 0:00:22
#      - ------------------------------------ 27.3/587.7 MB 25.8 MB/s eta 0:00:22
#      -- ----------------------------------- 31.5/587.7 MB 26.3 MB/s eta 0:00:22
#      -- ----------------------------------- 31.7/587.7 MB 21.4 MB/s eta 0:00:26
#      -- ----------------------------------- 35.1/587.7 MB 20.5 MB/s eta 0:00:27
#      -- ----------------------------------- 41.9/587.7 MB 21.9 MB/s eta 0:00:25
#      --- ---------------------------------- 49.0/587.7 MB 22.8 MB/s eta 0:00:24
#      --- ---------------------------------- 55.1/587.7 MB 23.4 MB/s eta 0:00:23
#      --- ---------------------------------- 61.3/587.7 MB 23.8 MB/s eta 0:00:23
#      ---- --------------------------------- 67.4/587.7 MB 24.3 MB/s eta 0:00:22
#      ---- --------------------------------- 73.7/587.7 MB 24.5 MB/s eta 0:00:22
#      ----- -------------------------------- 80.2/587.7 MB 25.0 MB/s eta 0:00:21
#      ----- -------------------------------- 86.5/587.7 MB 25.2 MB/s eta 0:00:20
587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  580.9/587.7 MB 26.7 MB/s eta 0:00:01
#      ------------------------------------  586.7/587.7 MB 26.5 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------  587.5/587.7 MB 26.6 MB/s eta 0:00:01
#      ------------------------------------- 587.7/587.7 MB 14.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from en-core-web-lg==3.5.0) (3.5.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.0.10)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.11.0)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.67.1)
# Requirement already satisfied: numpy>=1.15.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.24.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.10.21)
# Requirement already satisfied: jinja2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.1.6)
# Requirement already satisfied: setuptools in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (75.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\adam\appdata\roaming\python\python38\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4.1)
# Requirement already satisfied: language-data>=1.2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.3.0)
# Requirement already satisfied: pathlib-abc==0.1.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from pathy>=0.10.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.1.1)
# Requirement already satisfied: typing-extensions>=4.2.0 in c:\users\adam\appdata\roaming\python\python38\site-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2025.1.31)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from thinc<8.2.0,>=8.1.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.1.5)
# Requirement already satisfied: colorama in c:\users\adam\appdata\roaming\python\python38\site-packages (from tqdm<5.0.0,>=4.38.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (0.4.6)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (8.1.8)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (2.1.5)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy<3.6.0,>=3.5.0->en-core-web-lg==3.5.0) (1.2.1)
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.5.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')

# %%
# Load the en_core_web_lg embeddings

nlp = spacy.load('en_core_web_lg')

# %%
# View vector representation for the word 'banana'

print(nlp.vocab[u'banana'].vector)
# Out:
# [ 0.20778  -2.4151    0.36605   2.0139   -0.23752  -3.1952   -0.2952
#   1.2272   -3.4129   -0.54969   0.32634  -1.0813    0.55626   1.5195
#   0.97797  -3.1816   -0.37207  -0.86093   2.1509   -4.0845    0.035405
#   3.5702   -0.79413  -1.7025   -1.6371   -3.198    -1.9387    0.91166
#   0.85409   1.8039   -1.103    -2.5274    1.6365   -0.82082   1.0278
#  -1.705     1.5511   -0.95633  -1.4702   -1.865    -0.19324  -0.49123
#   2.2361    2.2119    3.6654    1.7943   -0.20601   1.5483   -1.3964
#  -0.50819   2.1288   -2.332     1.3539   -2.1917    1.8923    0.28472
#   0.54285   1.2309    0.26027   1.9542    1.1739   -0.40348   3.2028
#   0.75381  -2.7179   -1.3587   -1.1965   -2.0923    2.2855   -0.3058
#  -0.63174   0.70083   0.16899   1.2325    0.97006  -0.23356  -2.094
#  -1.737     3.6075   -1.511    -0.9135    0.53878   0.49268   0.44751
#   0.6315    1.4963    4.1725    2.1961   -1.2409    0.4214    2.9678
#   1.841     3.0133   -4.4652    0.96521  -0.29787   4.3386   -1.2527
#  -1.7734   -3.5637   -0.20035  -3.3013    0.99951  -0.92888  -0.94594
#   1.5124   -3.9385    2.7935   -3.1042    3.3382    0.54513  -0.37663
#   2.5151    0.51468  -0.88907   1.011     3.4705   -3.6037    1.3702
#   2.3468    1.6674    1.3904   -2.8112    2.237    -1.0344   -0.57164
#   1.0641   -1.6919    1.958    -0.78305   0.14741   0.51083   1.8278
#  -0.69638   0.90548   0.62282  -1.8315   -2.8587    0.48424  -2.0527
#  -0.53808  -2.3472    1.0354   -1.8257   -0.3892   -0.24943   0.8651
#  -1.5195    1.2166   -2.698    -0.96698   2.2175   -0.16089  -0.49677
#  -0.19646   1.3284    4.0824    1.3919    0.80669  -1.0316   -0.28056
#  -1.8632    0.47716  -0.53628   1.3853   -2.1755   -0.2354    2.4933
#  -0.87255   1.4493   -0.10778  -0.44159   1.3462    4.4211   -1.8385
#   0.3985    0.47637  -0.60074   3.3583   -0.15006  -0.40495   2.7225
#  -1.6297    0.86797  -4.1445   -2.7793    1.1535   -0.011691  0.9792
#  -1.0141    0.80134   0.43642   1.4337    2.8927    0.82871  -1.1827
#  -1.3838    2.3903   -0.89323   1.1461   -1.7435    0.8654   -0.27075
#  -0.78698   1.5631   -0.5923    0.098082 -0.26682   1.6282   -0.77495
#   3.2552    1.7964   -1.4314    1.2336    2.3102   -1.6328    2.8366
#  -0.71384   0.43967   1.5627    3.079    -0.922    -0.43981  -0.7659
#   1.9362   -2.2479    1.041     0.63206   1.5855    3.4097   -2.9204
#  -1.4751   -0.59534  -1.688    -4.1362    2.745    -2.8515    3.6509
#  -0.66993  -2.8794    2.0733    1.1779   -2.0307    2.595    -0.12246
#   1.5844    1.1855    0.022385 -2.2916   -2.2684   -2.7537    0.34981
#  -4.6243   -0.96521  -1.1435   -2.8894   -0.12619   2.9577   -1.7227
#   0.24757   1.2149    3.5349   -0.95802   0.080346 -1.6553   -0.6734
#   2.2918   -1.8229   -1.1336    1.8884    2.4789   -0.66061   2.0529
#  -0.76687   0.32362  -2.2579    0.91278   0.36231   0.61562  -0.15396
#  -0.42917  -0.89848   0.17298  -0.76978  -2.0222   -1.7127   -1.5632
#   0.56631  -1.354     2.6261    1.9156   -1.5651    1.8315   -1.4257
#  -1.6861   -0.51953   1.7635   -0.50722   1.388    -1.1012  ]

# %%
# %pip install -U scipy
# Out:
# Collecting scipy
#   Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl.metadata (58 kB)
# Requirement already satisfied: numpy<1.27.0,>=1.19.5 in c:\users\adam\appdata\local\programs\python\python38\lib\site-packages (from scipy) (1.24.4)
# Downloading scipy-1.10.1-cp38-cp38-win_amd64.whl (42.2 MB)
#    ---------------------------------------- 0.0/42.2 MB ? eta -:--:--
#    ------- -------------------------------- 8.4/42.2 MB 47.5 MB/s eta 0:00:01
#    ------------------ --------------------- 19.9/42.2 MB 50.4 MB/s eta 0:00:01
#    ------------------------------ --------- 31.7/42.2 MB 51.7 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 52.7 MB/s eta 0:00:01
#    ---------------------------------------  42.2/42.2 MB 52.7 MB/s eta 0:00:01
#    ---------------------------------------- 42.2/42.2 MB 36.8 MB/s eta 0:00:00
# Installing collected packages: scipy
# Successfully installed scipy-1.10.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# Word embedding Math: "queen" = "king"

from scipy import spatial

cosine_similarity = lambda x, y: 1 - spatial.distance.cosine(x, y)

man = nlp.vocab[u'man'].vector
woman = nlp.vocab[u'woman'].vector
queen = nlp.vocab[u'queen'].vector
king = nlp.vocab[u'king'].vector

# We now need to find the closest vector in the vocabulary to the result of "man" - "woman" + "queen"
maybe_king = man - woman + queen
computed_similarities = []

for word in nlp.vocab:
    # Ignore words without vectors
    if not word.has_vector:
        continue

    similarity = cosine_similarity(maybe_king, word.vector)
    computed_similarities.append((word, similarity))

computed_similarities = sorted(computed_similarities, key=lambda item: -item[1])
print([w[0].text for w in computed_similarities[:10]])

# ['Queen', 'QUEEN', 'queen', 'King', 'KING', 'king', 'KIng', 'KINGS', 'kings', 'Kings']
# Out:
# ['queen', 'man', 'king', 'woman', 'he', 'nothin’', "'cause", "'Cause", 'He', 'That']

# %%
# Computing Similiarity

banana = nlp.vocab[u'banana']
dog = nlp.vocab[u'dog']
fruit = nlp.vocab[u'fruit']
animal = nlp.vocab[u'animal']

print(dog.similarity(animal), dog.similarity(fruit)) # 0.6618534 0.23552845
print(banana.similarity(fruit), banana.similarity(animal)) # 0.67148364 0.2427285
# Out:
# 0.5192115902900696 0.13643456995487213
# 0.6650428175926208 0.18752224743366241

# %%
# Computing Similarity on entire texts

target = nlp(u"Cats are beautiful animals.")

doc1 = nlp(u"Dogs are awesome.")
doc2 = nlp(u"Some gorgeous creatures are felines.")
doc3 = nlp(u"Dolphins are swimming mammals.")

print(target.similarity(doc1))  # 0.8901765218466683
print(target.similarity(doc2))  # 0.9115828449161616
print(target.similarity(doc3))  # 0.7822956752876101
# Out:
# 0.925293344292394
# 0.9067517259890845
# 0.9037427153904276
